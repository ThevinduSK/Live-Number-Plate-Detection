# %%
from ultralytics import YOLO
import cv2

import util
from sort.sort import *
from util import get_car, read_license_plate, write_csv
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
from ultralytics import YOLO
import cv2

import util
from sort.sort import *
from util import get_car, read_license_plate, write_csv


results = {}

mot_tracker = Sort()

# load models
coco_model = YOLO('yolo11n.pt')
license_plate_detector = YOLO('detection_model.pt')

# load video
cap = cv2.VideoCapture('./test2.mp4')

vehicles = [2, 3, 5, 7]

# read frames
frame_nmr = -1
ret = True
while ret:
    frame_nmr += 1
    ret, frame = cap.read()
    if ret:
        results[frame_nmr] = {}
        # detect vehicles
        detections = coco_model(frame)[0]
        detections_ = []
        for detection in detections.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = detection
            if int(class_id) in vehicles:
                detections_.append([x1, y1, x2, y2, score])

        # track vehicles
        track_ids = mot_tracker.update(np.asarray(detections_))

        # detect license plates
        license_plates = license_plate_detector(frame)[0]
        for license_plate in license_plates.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = license_plate

            # assign license plate to car
            xcar1, ycar1, xcar2, ycar2, car_id = get_car(license_plate, track_ids)

            if car_id != -1:

                # crop license plate
                license_plate_crop = frame[int(y1):int(y2), int(x1): int(x2), :]

                # process license plate
                license_plate_crop_gray = cv2.cvtColor(license_plate_crop, cv2.COLOR_BGR2GRAY)
                _, license_plate_crop_thresh = cv2.threshold(license_plate_crop_gray, 64, 255, cv2.THRESH_BINARY_INV)

                # read license plate number
                license_plate_text, license_plate_text_score = read_license_plate(license_plate_crop_thresh)

                if license_plate_text is not None:
                    results[frame_nmr][car_id] = {'car': {'bbox': [xcar1, ycar1, xcar2, ycar2]},
                                                  'license_plate': {'bbox': [x1, y1, x2, y2],
                                                                    'text': license_plate_text,
                                                                    'bbox_score': score,
                                                                    'text_score': license_plate_text_score}}

# write results
write_csv(results, './test.csv')
# Out:
# 0: 480x640 2 cars, 74.5ms
# Speed: 2.4ms preprocess, 74.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.8ms
# Speed: 1.6ms preprocess, 63.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 67.9ms
# Speed: 1.7ms preprocess, 67.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.2ms
# Speed: 2.2ms preprocess, 57.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 train, 56.7ms
# Speed: 2.9ms preprocess, 56.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.2ms
# Speed: 2.3ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 train, 63.1ms
# Speed: 2.1ms preprocess, 63.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 67.1ms
# Speed: 2.0ms preprocess, 67.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 train, 64.8ms
# Speed: 2.4ms preprocess, 64.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.8ms
# Speed: 1.9ms preprocess, 62.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 train, 60.6ms
# Speed: 2.1ms preprocess, 60.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.5ms
# Speed: 2.2ms preprocess, 63.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 train, 65.7ms
# Speed: 2.1ms preprocess, 65.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.6ms
# Speed: 1.7ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 train, 88.9ms
# Speed: 1.8ms preprocess, 88.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.9ms
# Speed: 3.8ms preprocess, 51.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 59.3ms
# Speed: 2.9ms preprocess, 59.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.7ms
# Speed: 11.5ms preprocess, 52.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 60.3ms
# Speed: 1.7ms preprocess, 60.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.8ms
# Speed: 1.9ms preprocess, 59.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 airplane, 1 train, 62.1ms
# Speed: 1.8ms preprocess, 62.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.1ms
# Speed: 1.7ms preprocess, 59.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 airplane, 1 train, 59.1ms
# Speed: 1.9ms preprocess, 59.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.0ms
# Speed: 1.6ms preprocess, 51.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 train, 65.1ms
# Speed: 2.4ms preprocess, 65.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.2ms
# Speed: 1.7ms preprocess, 61.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 62.8ms
# Speed: 2.3ms preprocess, 62.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.5ms
# Speed: 2.1ms preprocess, 57.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 62.2ms
# Speed: 1.9ms preprocess, 62.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.6ms
# Speed: 2.3ms preprocess, 59.6ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 55.8ms
# Speed: 1.9ms preprocess, 55.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.5ms
# Speed: 2.2ms preprocess, 62.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 62.8ms
# Speed: 1.9ms preprocess, 62.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.5ms
# Speed: 2.3ms preprocess, 59.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 63.7ms
# Speed: 1.9ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 65.1ms
# Speed: 1.7ms preprocess, 65.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 train, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.0ms
# Speed: 1.9ms preprocess, 63.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 airplane, 1 train, 52.7ms
# Speed: 2.3ms preprocess, 52.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.3ms
# Speed: 2.1ms preprocess, 52.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 airplane, 65.4ms
# Speed: 1.8ms preprocess, 65.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.2ms
# Speed: 2.2ms preprocess, 59.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 airplane, 60.7ms
# Speed: 1.7ms preprocess, 60.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.9ms
# Speed: 2.1ms preprocess, 63.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 airplane, 1 train, 60.5ms
# Speed: 1.8ms preprocess, 60.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.5ms
# Speed: 1.9ms preprocess, 48.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 61.9ms
# Speed: 2.0ms preprocess, 61.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.7ms
# Speed: 2.2ms preprocess, 61.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 train, 61.0ms
# Speed: 1.8ms preprocess, 61.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.2ms
# Speed: 2.0ms preprocess, 63.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 train, 64.2ms
# Speed: 2.1ms preprocess, 64.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.6ms
# Speed: 1.6ms preprocess, 51.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 train, 53.3ms
# Speed: 1.9ms preprocess, 53.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.5ms
# Speed: 1.9ms preprocess, 62.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 63.8ms
# Speed: 1.9ms preprocess, 63.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.7ms
# Speed: 1.7ms preprocess, 59.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 airplane, 62.1ms
# Speed: 1.8ms preprocess, 62.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.3ms
# Speed: 1.8ms preprocess, 59.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 airplane, 64.0ms
# Speed: 1.7ms preprocess, 64.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.9ms
# Speed: 1.8ms preprocess, 50.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 airplane, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.3ms
# Speed: 1.9ms preprocess, 60.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 airplane, 64.1ms
# Speed: 1.6ms preprocess, 64.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.2ms
# Speed: 1.7ms preprocess, 60.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 airplane, 62.7ms
# Speed: 2.4ms preprocess, 62.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.9ms
# Speed: 2.0ms preprocess, 50.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 airplane, 53.0ms
# Speed: 1.8ms preprocess, 53.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63
# {'car': {'bbox': [394.69786382222287, 185.56562464392428, 650.8809714446772, 398.76171654950656]}, 'license_plate': {'bbox': [487.66131591796875, 316.22198486328125, 571.1906127929688, 340.8400573730469], 'text': 'DA54TLC', 'bbox_score': 0.690112292766571, 'text_score': 0.12715514917943527}}
# {'car': {'bbox': [395.616219715359, 185.98822206709843, 651.4086496999415, 399.16830489359774]}, 'license_plate': {'bbox': [487.4462585449219, 316.00433349609375, 571.2360229492188, 340.6930236816406], 'text': 'DI59ILL', 'bbox_score': 0.6880485415458679, 'text_score': 0.02606514955652842}}
# {'car': {'bbox': [393.99289004039974, 186.03288155463719, 650.6278060887869, 398.8240788122085]}, 'license_plate': {'bbox': [487.23626708984375, 315.97882080078125, 571.4345703125, 341.0630798339844], 'text': 'VI59TLL', 'bbox_score': 0.700017511844635, 'text_score': 0.02756083968100004}}
# {'car': {'bbox': [395.16500066826814, 185.38087522830386, 650.8566618377309, 398.67504741077795]}, 'license_plate': {'bbox': [487.253173828125, 315.963623046875, 571.5404663085938, 340.99029541015625], 'text': 'DI53MLL', 'bbox_score': 0.6965448260307312, 'text_score': 0.13423665956855613}}
# {'car': {'bbox': [395.1863089988814, 185.17286256674242, 650.6752291087533, 398.65375014692825]}, 'license_plate': {'bbox': [487.27532958984375, 315.9356994628906, 571.5800170898438, 340.9249267578125], 'text': 'DI59RLL', 'bbox_score': 0.6955299377441406, 'text_score': 0.010656642550833975}}

# %%
import csv
import numpy as np
from scipy.interpolate import interp1d


def interpolate_bounding_boxes(data):
    # Extract necessary data columns from input data
    frame_numbers = np.array([int(row['frame_nmr']) for row in data])
    car_ids = np.array([int(float(row['car_id'])) for row in data])
    car_bboxes = np.array([list(map(float, row['car_bbox'][1:-1].split())) for row in data])
    license_plate_bboxes = np.array([list(map(float, row['license_plate_bbox'][1:-1].split())) for row in data])

    interpolated_data = []
    unique_car_ids = np.unique(car_ids)
    for car_id in unique_car_ids:

        frame_numbers_ = [p['frame_nmr'] for p in data if int(float(p['car_id'])) == int(float(car_id))]
        print(frame_numbers_, car_id)

        # Filter data for a specific car ID
        car_mask = car_ids == car_id
        car_frame_numbers = frame_numbers[car_mask]
        car_bboxes_interpolated = []
        license_plate_bboxes_interpolated = []

        first_frame_number = car_frame_numbers[0]
        last_frame_number = car_frame_numbers[-1]

        for i in range(len(car_bboxes[car_mask])):
            frame_number = car_frame_numbers[i]
            car_bbox = car_bboxes[car_mask][i]
            license_plate_bbox = license_plate_bboxes[car_mask][i]

            if i > 0:
                prev_frame_number = car_frame_numbers[i-1]
                prev_car_bbox = car_bboxes_interpolated[-1]
                prev_license_plate_bbox = license_plate_bboxes_interpolated[-1]

                if frame_number - prev_frame_number > 1:
                    # Interpolate missing frames' bounding boxes
                    frames_gap = frame_number - prev_frame_number
                    x = np.array([prev_frame_number, frame_number])
                    x_new = np.linspace(prev_frame_number, frame_number, num=frames_gap, endpoint=False)
                    interp_func = interp1d(x, np.vstack((prev_car_bbox, car_bbox)), axis=0, kind='linear')
                    interpolated_car_bboxes = interp_func(x_new)
                    interp_func = interp1d(x, np.vstack((prev_license_plate_bbox, license_plate_bbox)), axis=0, kind='linear')
                    interpolated_license_plate_bboxes = interp_func(x_new)

                    car_bboxes_interpolated.extend(interpolated_car_bboxes[1:])
                    license_plate_bboxes_interpolated.extend(interpolated_license_plate_bboxes[1:])

            car_bboxes_interpolated.append(car_bbox)
            license_plate_bboxes_interpolated.append(license_plate_bbox)

        for i in range(len(car_bboxes_interpolated)):
            frame_number = first_frame_number + i
            row = {}
            row['frame_nmr'] = str(frame_number)
            row['car_id'] = str(car_id)
            row['car_bbox'] = ' '.join(map(str, car_bboxes_interpolated[i]))
            row['license_plate_bbox'] = ' '.join(map(str, license_plate_bboxes_interpolated[i]))

            if str(frame_number) not in frame_numbers_:
                # Imputed row, set the following fields to '0'
                row['license_plate_bbox_score'] = '0'
                row['license_number'] = '0'
                row['license_number_score'] = '0'
            else:
                # Original row, retrieve values from the input data if available
                original_row = [p for p in data if int(p['frame_nmr']) == frame_number and int(float(p['car_id'])) == int(float(car_id))][0]
                row['license_plate_bbox_score'] = original_row['license_plate_bbox_score'] if 'license_plate_bbox_score' in original_row else '0'
                row['license_number'] = original_row['license_number'] if 'license_number' in original_row else '0'
                row['license_number_score'] = original_row['license_number_score'] if 'license_number_score' in original_row else '0'

            interpolated_data.append(row)

    return interpolated_data


# Load the CSV file
with open('test.csv', 'r') as file:
    reader = csv.DictReader(file)
    data = list(reader)

# Interpolate missing data
interpolated_data = interpolate_bounding_boxes(data)

# Write updated data to a new CSV file
header = ['frame_nmr', 'car_id', 'car_bbox', 'license_plate_bbox', 'license_plate_bbox_score', 'license_number', 'license_number_score']
with open('test_interpolated.csv', 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=header)
    writer.writeheader()
    writer.writerows(interpolated_data)
# Out:
# ['238', '239', '240', '241', '242', '243', '244', '245', '246', '247', '248', '249', '250', '251', '252', '253', '254', '255', '256', '257', '258', '259', '260', '261', '262', '263', '264', '265', '266', '267', '268', '269', '270', '271', '272', '273', '274', '275', '276', '277', '278', '279', '281', '282', '283', '285', '293', '294', '295', '297', '298', '299', '300', '301', '302', '303', '304', '305', '306', '307', '308', '309', '310', '311', '312', '314', '315', '316', '317', '318', '319', '320', '321', '322', '325', '330', '332', '335', '336', '337', '339', '340', '341', '350', '351', '353', '358', '368', '370', '371', '372', '373', '378', '385', '386', '395', '407', '408', '409', '415', '421', '428', '438', '439', '459', '463', '464', '465', '466', '467', '468', '562', '567', '568', '578', '579', '592', '601', '619', '620'] 84

# %%
import ast

import cv2
import numpy as np
import pandas as pd


def draw_border(img, top_left, bottom_right, color=(0, 255, 0), thickness=10, line_length_x=200, line_length_y=200):
    x1, y1 = top_left
    x2, y2 = bottom_right

    cv2.line(img, (x1, y1), (x1, y1 + line_length_y), color, thickness)  #-- top-left
    cv2.line(img, (x1, y1), (x1 + line_length_x, y1), color, thickness)

    cv2.line(img, (x1, y2), (x1, y2 - line_length_y), color, thickness)  #-- bottom-left
    cv2.line(img, (x1, y2), (x1 + line_length_x, y2), color, thickness)

    cv2.line(img, (x2, y1), (x2 - line_length_x, y1), color, thickness)  #-- top-right
    cv2.line(img, (x2, y1), (x2, y1 + line_length_y), color, thickness)

    cv2.line(img, (x2, y2), (x2, y2 - line_length_y), color, thickness)  #-- bottom-right
    cv2.line(img, (x2, y2), (x2 - line_length_x, y2), color, thickness)

    return img


results = pd.read_csv('./test_interpolated.csv')

# load video
video_path = 'test2.mp4'
cap = cv2.VideoCapture(video_path)

fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Specify the codec
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter('./out.mp4', fourcc, fps, (width, height))

license_plate = {}
for car_id in np.unique(results['car_id']):
    max_ = np.amax(results[results['car_id'] == car_id]['license_number_score'])
    license_plate[car_id] = {'license_crop': None,
                             'license_plate_number': results[(results['car_id'] == car_id) &
                                                             (results['license_number_score'] == max_)]['license_number'].iloc[0]}
    cap.set(cv2.CAP_PROP_POS_FRAMES, results[(results['car_id'] == car_id) &
                                             (results['license_number_score'] == max_)]['frame_nmr'].iloc[0])
    ret, frame = cap.read()

    x1, y1, x2, y2 = ast.literal_eval(results[(results['car_id'] == car_id) &
                                              (results['license_number_score'] == max_)]['license_plate_bbox'].iloc[0].replace('[ ', '[').replace('   ', ' ').replace('  ', ' ').replace(' ', ','))

    license_crop = frame[int(y1):int(y2), int(x1):int(x2), :]
    license_crop = cv2.resize(license_crop, (int((x2 - x1) * 400 / (y2 - y1)), 400))

    license_plate[car_id]['license_crop'] = license_crop


frame_nmr = -1

cap.set(cv2.CAP_PROP_POS_FRAMES, 0)

# read frames
ret = True
while ret:
    ret, frame = cap.read()
    frame_nmr += 1
    if ret:
        df_ = results[results['frame_nmr'] == frame_nmr]
        for row_indx in range(len(df_)):
            # draw car
            car_x1, car_y1, car_x2, car_y2 = ast.literal_eval(df_.iloc[row_indx]['car_bbox'].replace('[ ', '[').replace('   ', ' ').replace('  ', ' ').replace(' ', ','))
            draw_border(frame, (int(car_x1), int(car_y1)), (int(car_x2), int(car_y2)), (0, 255, 0), 25,
                        line_length_x=200, line_length_y=200)

            # draw license plate
            x1, y1, x2, y2 = ast.literal_eval(df_.iloc[row_indx]['license_plate_bbox'].replace('[ ', '[').replace('   ', ' ').replace('  ', ' ').replace(' ', ','))
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 0, 255), 12)

            # crop license plate
            license_crop = license_plate[df_.iloc[row_indx]['car_id']]['license_crop']

            H, W, _ = license_crop.shape

            try:
                frame[int(car_y1) - H - 100:int(car_y1) - 100,
                      int((car_x2 + car_x1 - W) / 2):int((car_x2 + car_x1 + W) / 2), :] = license_crop

                frame[int(car_y1) - H - 400:int(car_y1) - H - 100,
                      int((car_x2 + car_x1 - W) / 2):int((car_x2 + car_x1 + W) / 2), :] = (255, 255, 255)

                (text_width, text_height), _ = cv2.getTextSize(
                    license_plate[df_.iloc[row_indx]['car_id']]['license_plate_number'],
                    cv2.FONT_HERSHEY_SIMPLEX,
                    4.3,
                    17)

                cv2.putText(frame,
                            license_plate[df_.iloc[row_indx]['car_id']]['license_plate_number'],
                            (int((car_x2 + car_x1 - text_width) / 2), int(car_y1 - H - 250 + (text_height / 2))),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            4.3,
                            (0, 0, 0),
                            17)

            except:
                pass

        out.write(frame)
        frame = cv2.resize(frame, (1280, 720))

        # cv2.imshow('frame', frame)
        # cv2.waitKey(0)

out.release()
cap.release()

# %%
from ultralytics import YOLO
import cv2

import util
from sort.sort import *
from util import get_car, read_license_plate, write_csv


results = {}

mot_tracker = Sort()

# load models
coco_model = YOLO('yolo11n.pt')
license_plate_detector = YOLO('detection_model.pt')

# load video
cap = cv2.VideoCapture('./test2.mp4')

vehicles = [2, 3, 5, 7]

# read frames
frame_nmr = -1
ret = True
while ret:
    frame_nmr += 1
    ret, frame = cap.read()
    if ret:
        results[frame_nmr] = {}
        # detect vehicles
        detections = coco_model(frame)[0]
        detections_ = []
        for detection in detections.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = detection
            if int(class_id) in vehicles:
                detections_.append([x1, y1, x2, y2, score])

        # track vehicles
        track_ids = mot_tracker.update(np.asarray(detections_))

        # detect license plates
        license_plates = license_plate_detector(frame)[0]
        for license_plate in license_plates.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = license_plate

            # assign license plate to car
            xcar1, ycar1, xcar2, ycar2, car_id = get_car(license_plate, track_ids)

            if car_id != -1:

                # crop license plate
                license_plate_crop = frame[int(y1):int(y2), int(x1): int(x2), :]

                # process license plate
                license_plate_crop_gray = cv2.cvtColor(license_plate_crop, cv2.COLOR_BGR2GRAY)
                _, license_plate_crop_thresh = cv2.threshold(license_plate_crop_gray, 64, 255, cv2.THRESH_BINARY_INV)

                # read license plate number
                license_plate_text, license_plate_text_score = read_license_plate(license_plate_crop_thresh)

                if license_plate_text is not None:
                    results[frame_nmr][car_id] = {'car': {'bbox': [xcar1, ycar1, xcar2, ycar2]},
                                                  'license_plate': {'bbox': [x1, y1, x2, y2],
                                                                    'text': license_plate_text,
                                                                    'bbox_score': score,
                                                                    'text_score': license_plate_text_score}}

# write results
write_csv(results, './test.csv')
# Out:
# 0: 480x640 2 cars, 74.5ms
# Speed: 2.4ms preprocess, 74.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.8ms
# Speed: 1.6ms preprocess, 63.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 67.9ms
# Speed: 1.7ms preprocess, 67.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.2ms
# Speed: 2.2ms preprocess, 57.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 train, 56.7ms
# Speed: 2.9ms preprocess, 56.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.2ms
# Speed: 2.3ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 train, 63.1ms
# Speed: 2.1ms preprocess, 63.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 67.1ms
# Speed: 2.0ms preprocess, 67.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 train, 64.8ms
# Speed: 2.4ms preprocess, 64.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.8ms
# Speed: 1.9ms preprocess, 62.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 train, 60.6ms
# Speed: 2.1ms preprocess, 60.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.5ms
# Speed: 2.2ms preprocess, 63.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 train, 65.7ms
# Speed: 2.1ms preprocess, 65.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.6ms
# Speed: 1.7ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 train, 88.9ms
# Speed: 1.8ms preprocess, 88.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.9ms
# Speed: 3.8ms preprocess, 51.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 59.3ms
# Speed: 2.9ms preprocess, 59.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.7ms
# Speed: 11.5ms preprocess, 52.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 60.3ms
# Speed: 1.7ms preprocess, 60.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.8ms
# Speed: 1.9ms preprocess, 59.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 airplane, 1 train, 62.1ms
# Speed: 1.8ms preprocess, 62.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.1ms
# Speed: 1.7ms preprocess, 59.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 airplane, 1 train, 59.1ms
# Speed: 1.9ms preprocess, 59.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.0ms
# Speed: 1.6ms preprocess, 51.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 train, 65.1ms
# Speed: 2.4ms preprocess, 65.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.2ms
# Speed: 1.7ms preprocess, 61.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 62.8ms
# Speed: 2.3ms preprocess, 62.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.5ms
# Speed: 2.1ms preprocess, 57.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 62.2ms
# Speed: 1.9ms preprocess, 62.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.6ms
# Speed: 2.3ms preprocess, 59.6ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 55.8ms
# Speed: 1.9ms preprocess, 55.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.5ms
# Speed: 2.2ms preprocess, 62.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 62.8ms
# Speed: 1.9ms preprocess, 62.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.5ms
# Speed: 2.3ms preprocess, 59.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 63.7ms
# Speed: 1.9ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 65.1ms
# Speed: 1.7ms preprocess, 65.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 train, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.0ms
# Speed: 1.9ms preprocess, 63.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 airplane, 1 train, 52.7ms
# Speed: 2.3ms preprocess, 52.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.3ms
# Speed: 2.1ms preprocess, 52.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 airplane, 65.4ms
# Speed: 1.8ms preprocess, 65.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.2ms
# Speed: 2.2ms preprocess, 59.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 airplane, 60.7ms
# Speed: 1.7ms preprocess, 60.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.9ms
# Speed: 2.1ms preprocess, 63.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 1 airplane, 1 train, 60.5ms
# Speed: 1.8ms preprocess, 60.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48
# {'car': {'bbox': [394.689457326724, 185.5337627782606, 651.0091011384867, 398.7928661519948]}, 'license_plate': {'bbox': [487.6551818847656, 316.1700744628906, 571.146240234375, 340.8546142578125], 'text': 'DA54TLC', 'bbox_score': 0.691496729850769, 'text_score': 0.12715514917943527}}
# {'car': {'bbox': [394.69786382222287, 185.56562464392428, 650.8809714446772, 398.76171654950656]}, 'license_plate': {'bbox': [487.66131591796875, 316.22198486328125, 571.1906127929688, 340.8400573730469], 'text': 'DA54TLC', 'bbox_score': 0.690112292766571, 'text_score': 0.12715514917943527}}
# {'car': {'bbox': [395.616219715359, 185.98822206709843, 651.4086496999415, 399.16830489359774]}, 'license_plate': {'bbox': [487.4462585449219, 316.00433349609375, 571.2360229492188, 340.6930236816406], 'text': 'DI59ILL', 'bbox_score': 0.6880485415458679, 'text_score': 0.02606514955652842}}
# {'car': {'bbox': [393.99289004039974, 186.03288155463719, 650.6278060887869, 398.8240788122085]}, 'license_plate': {'bbox': [487.23626708984375, 315.97882080078125, 571.4345703125, 341.0630798339844], 'text': 'VI59TLL', 'bbox_score': 0.700017511844635, 'text_score': 0.02756083968100004}}
# {'car': {'bbox': [395.16500066826814, 185.38087522830386, 650.8566618377309, 398.67504741077795]}, 'license_plate': {'bbox': [487.253173828125, 315.963623046875, 571.5404663085938, 340.99029541015625], 'text': 'DI53MLL', 'bbox_score': 0.6965448260307312, 'text_score': 0.13423665956855613}}
# {'car': {'bbox': [395.1863089988814, 185.17286256674242, 650.6752291087533, 398.65375014692825]}, 'license_plate': {'bbox': [487.27532958984375, 315.9356994628906, 571.5800170898438, 340.9249267578125], 'text': 'DI59RLL', 'bbox_score': 0.6955299377441406, 'text_score': 0.010656642550833975}}

# %%
import ast
import cv2
import numpy as np
import pandas as pd


def draw_border(img, top_left, bottom_right, color=(0, 255, 0), thickness=10, line_length_x=200, line_length_y=200):
    x1, y1 = top_left
    x2, y2 = bottom_right

    cv2.line(img, (x1, y1), (x1, y1 + line_length_y), color, thickness)  #-- top-left
    cv2.line(img, (x1, y1), (x1 + line_length_x, y1), color, thickness)

    cv2.line(img, (x1, y2), (x1, y2 - line_length_y), color, thickness)  #-- bottom-left
    cv2.line(img, (x1, y2), (x1 + line_length_x, y2), color, thickness)

    cv2.line(img, (x2, y1), (x2 - line_length_x, y1), color, thickness)  #-- top-right
    cv2.line(img, (x2, y1), (x2, y1 + line_length_y), color, thickness)

    cv2.line(img, (x2, y2), (x2, y2 - line_length_y), color, thickness)  #-- bottom-right
    cv2.line(img, (x2, y2), (x2 - line_length_x, y2), color, thickness)

    return img


results = pd.read_csv('./test_interpolated.csv')

# load video
video_path = 'test2.mp4'
cap = cv2.VideoCapture(video_path)

fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Specify the codec
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter('./out.mp4', fourcc, fps, (width, height))

license_plate = {}
for car_id in np.unique(results['car_id']):
    try:
        # Check if license_number_score column exists and has valid data
        if 'license_number_score' not in results.columns or results[results['car_id'] == car_id]['license_number_score'].empty:
            print(f"Warning: No license_number_score for car_id {car_id}")
            continue
            
        max_ = np.amax(results[results['car_id'] == car_id]['license_number_score'])
        
        # Verify we have license number data
        if 'license_number' not in results.columns or results[(results['car_id'] == car_id) & 
                                               (results['license_number_score'] == max_)]['license_number'].empty:
            print(f"Warning: No license_number for car_id {car_id}")
            continue
            
        license_number = results[(results['car_id'] == car_id) & 
                                (results['license_number_score'] == max_)]['license_number'].iloc[0]
        
        license_plate[car_id] = {
            'license_crop': None,
            'license_plate_number': license_number
        }
        
        frame_nmr = results[(results['car_id'] == car_id) & 
                          (results['license_number_score'] == max_)]['frame_nmr'].iloc[0]
        
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_nmr)
        ret, frame = cap.read()
        
        if not ret:
            print(f"Warning: Could not read frame {frame_nmr} for car_id {car_id}")
            continue

        bbox_str = results[(results['car_id'] == car_id) & 
                          (results['license_number_score'] == max_)]['license_plate_bbox'].iloc[0]
        x1, y1, x2, y2 = ast.literal_eval(bbox_str.replace('[ ', '[').replace('   ', ' ').replace('  ', ' ').replace(' ', ','))

        # Make sure coordinates are within frame bounds
        y1, y2 = max(0, int(y1)), min(frame.shape[0], int(y2))
        x1, x2 = max(0, int(x1)), min(frame.shape[1], int(x2))
        
        if x2 <= x1 or y2 <= y1:
            print(f"Warning: Invalid bbox dimensions for car_id {car_id}")
            continue
            
        license_crop = frame[y1:y2, x1:x2, :]
        license_crop = cv2.resize(license_crop, (int((x2 - x1) * 400 / (y2 - y1)), 400))

        license_plate[car_id]['license_crop'] = license_crop
        
    except Exception as e:
        print(f"Error processing car_id {car_id}: {e}")


frame_nmr = -1

cap.set(cv2.CAP_PROP_POS_FRAMES, 0)

# read frames
ret = True
while ret:
    ret, frame = cap.read()
    frame_nmr += 1
    if ret:
        df_ = results[results['frame_nmr'] == frame_nmr]
        for row_indx in range(len(df_)):
            try:
                # draw car
                car_bbox_str = df_.iloc[row_indx]['car_bbox'].replace('[ ', '[').replace('   ', ' ').replace('  ', ' ').replace(' ', ',')
                car_x1, car_y1, car_x2, car_y2 = ast.literal_eval(car_bbox_str)
                draw_border(frame, (int(car_x1), int(car_y1)), (int(car_x2), int(car_y2)), (0, 255, 0), 25,
                            line_length_x=200, line_length_y=200)

                # draw license plate
                license_bbox_str = df_.iloc[row_indx]['license_plate_bbox'].replace('[ ', '[').replace('   ', ' ').replace('  ', ' ').replace(' ', ',')
                x1, y1, x2, y2 = ast.literal_eval(license_bbox_str)
                cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 0, 255), 12)

                # Get car_id and check if it exists in our dictionary
                car_id = df_.iloc[row_indx]['car_id']
                if car_id not in license_plate:
                    print(f"Warning: Car ID {car_id} not in license_plate dictionary (frame {frame_nmr})")
                    continue
                    
                # Get license crop and check if it exists
                license_crop = license_plate[car_id]['license_crop']
                if license_crop is None:
                    print(f"Warning: No license crop for car_id {car_id} (frame {frame_nmr})")
                    continue
                    
                # Get dimensions
                H, W, _ = license_crop.shape
                
                # Calculate positions
                top_y = int(car_y1) - H - 100
                bottom_y = int(car_y1) - 100
                left_x = int((car_x2 + car_x1 - W) / 2)
                right_x = int((car_x2 + car_x1 + W) / 2)
                
                # Ensure positions are within frame bounds
                if top_y < 0:
                    offset = abs(top_y)
                    top_y = 0
                    bottom_y = min(bottom_y + offset, frame.shape[0])
                    print(f"Adjusted top position for car_id {car_id} (frame {frame_nmr})")
                
                if left_x < 0:
                    left_x = 0
                    right_x = min(W, frame.shape[1])
                    print(f"Adjusted left position for car_id {car_id} (frame {frame_nmr})")
                    
                if right_x >= frame.shape[1]:
                    right_x = frame.shape[1] - 1
                    left_x = max(right_x - W, 0)
                    print(f"Adjusted right position for car_id {car_id} (frame {frame_nmr})")
                
                if bottom_y >= frame.shape[0]:
                    bottom_y = frame.shape[0] - 1
                    top_y = max(bottom_y - H, 0)
                    print(f"Adjusted bottom position for car_id {car_id} (frame {frame_nmr})")
                
                # Resize license_crop if needed to fit the available space
                actual_h = bottom_y - top_y
                actual_w = right_x - left_x
                
                if actual_h != H or actual_w != W:
                    if actual_h > 0 and actual_w > 0:
                        license_crop_resized = cv2.resize(license_crop, (actual_w, actual_h))
                        frame[top_y:bottom_y, left_x:right_x, :] = license_crop_resized
                        print(f"Resized license crop for car_id {car_id} (frame {frame_nmr})")
                else:
                    # Place license crop
                    frame[top_y:bottom_y, left_x:right_x, :] = license_crop
                
                # Calculate text background position
                text_top_y = int(car_y1) - H - 400
                text_bottom_y = int(car_y1) - H - 100
                
                # Adjust text background position if needed
                if text_top_y < 0:
                    offset = abs(text_top_y)
                    text_top_y = 0
                    text_bottom_y = min(text_bottom_y + offset, top_y)
                
                if text_bottom_y >= frame.shape[0]:
                    text_bottom_y = frame.shape[0] - 1
                    text_top_y = max(text_bottom_y - 300, 0)
                
                # Place white background for text
                bg_h = text_bottom_y - text_top_y
                bg_w = right_x - left_x
                
                if bg_h > 0 and bg_w > 0:
                    # Create white background
                    white_bg = np.ones((bg_h, bg_w, 3), dtype=np.uint8) * 255
                    frame[text_top_y:text_bottom_y, left_x:right_x, :] = white_bg
                    
                    # Add text
                    license_number = license_plate[car_id]['license_plate_number']
                    (text_width, text_height), _ = cv2.getTextSize(
                        license_number,
                        cv2.FONT_HERSHEY_SIMPLEX,
                        4.3,
                        17)
                    
                    # Calculate text position
                    text_x = int((car_x2 + car_x1 - text_width) / 2)
                    text_y = int((text_top_y + text_bottom_y + text_height) / 2)
                    
                    # Ensure text is within frame bounds
                    if text_x < 0:
                        text_x = left_x + 10
                    
                    # Draw text
                    cv2.putText(frame,
                                license_number,
                                (text_x, text_y),
                                cv2.FONT_HERSHEY_SIMPLEX,
                                4.3,
                                (0, 0, 0),
                                17)
                
            except Exception as e:
                print(f"Error processing row {row_indx} in frame {frame_nmr}: {e}")

        out.write(frame)
        frame = cv2.resize(frame, (1280, 720))
        
        # Uncomment to display frame
        # cv2.imshow('frame', frame)
        # cv2.waitKey(1)  # Changed from 0 to 1 for continuous playback

print("Video processing complete")
out.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# Adjusted top position for car_id 84 (frame 238)
# Adjusted left position for car_id 84 (frame 238)
# Adjusted right position for car_id 84 (frame 238)
# Resized license crop for car_id 84 (frame 238)
# Adjusted top position for car_id 84 (frame 239)
# Adjusted left position for car_id 84 (frame 239)
# Adjusted right position for car_id 84 (frame 239)
# Resized license crop for car_id 84 (frame 239)
# Adjusted top position for car_id 84 (frame 240)
# Adjusted left position for car_id 84 (frame 240)
# Adjusted right position for car_id 84 (frame 240)
# Resized license crop for car_id 84 (frame 240)
# Adjusted top position for car_id 84 (frame 241)
# Adjusted left position for car_id 84 (frame 241)
# Adjusted right position for car_id 84 (frame 241)
# Resized license crop for car_id 84 (frame 241)
# Adjusted top position for car_id 84 (frame 242)
# Adjusted left position for car_id 84 (frame 242)
# Adjusted right position for car_id 84 (frame 242)
# Resized license crop for car_id 84 (frame 242)
# Adjusted top position for car_id 84 (frame 243)
# Adjusted left position for car_id 84 (frame 243)
# Adjusted right position for car_id 84 (frame 243)
# Resized license crop for car_id 84 (frame 243)
# Adjusted top position for car_id 84 (frame 244)
# Adjusted left position for car_id 84 (frame 244)
# Adjusted right position for car_id 84 (frame 244)
# Resized license crop for car_id 84 (frame 244)
# Adjusted top position for car_id 84 (frame 245)
# Adjusted left position for car_id 84 (frame 245)
# Adjusted right position for car_id 84 (frame 245)
# Resized license crop for car_id 84 (frame 245)
# Adjusted top position for car_id 84 (frame 246)
# Adjusted left position for car_id 84 (frame 246)
# Adjusted right position for car_id 84 (frame 246)
# Resized license crop for car_id 84 (frame 246)
# Adjusted top position for car_id 84 (frame 247)
# Adjusted left position for car_id 84 (frame 247)
# Adjusted right position for car_id 84 (frame 247)
# Resized license crop for car_id 84 (frame 247)
# Adjusted top position for car_id 84 (frame 248)
# Adjusted left position for car_id 84 (frame 248)
# Adjusted right position for car_id 84 (frame 248)
# Resized license crop for car_id 84 (frame 248)
# Adjusted top position for car_id 84 (frame 249)
# Adjusted left position for car_id 84 (frame 249)
# Adjusted right position for car_id 84 (frame 249)
# Resized license crop for car_id 84 (frame 249)
# Adjusted top position for car_id 84 (frame 250)
# Adjusted left position for car_id 84 (frame 250)
# Adjusted right position for car_id 84 (frame 250)
# Resized license crop for car_id 84 (frame 250)
# Adjusted top position for car_id 84 (frame 251)
# Adjusted left position for car_id 84 (frame 251)
# Adjusted right position for car_id 84 (frame 251)
# Resized license crop for car_id 84 (frame 251)
# Adjusted top position for car_id 84 (frame 252)
# Adjusted left position for car_id 84 (frame 252)
# Adjusted right position for car_id 84 (frame 252)
# Resized license crop for car_id 84 (frame 252)
# Adjusted top position for car_id 84 (frame 253)
# Adjusted left position for car_id 84 (frame 253)
# Adjusted right position for car_id 84 (frame 253)
# Resized license crop for car_id 84 (frame 253)
# Adjusted top position for car_id 84 (frame 254)
# Adjusted left position for car_id 84 (frame 254)
# Adjusted right position for car_id 84 (frame 254)
# Resized license crop for car_id 84 (frame 254)
# Adjusted top position for car_id 84 (frame 255)
# Adjusted left position for car_id 84 (frame 255)
# Adjusted right position for car_id 84 (frame 255)
# Resized license crop for car_id 84 (frame 255)
# Adjusted top position for car_id 84 (frame 256)
# Adjusted left position for car_id 84 (frame 256)
# Adjusted right position for car_id 84 (frame 256)
# Resized license crop for car_id 84 (frame 256)
# Adjusted top position for car_id 84 (frame 257)
# Adjusted left position for car_id 84 (frame 257)
# Adjusted right position for car_id 84 (frame 257)
# Resized license crop for car_id 84 (frame 257)
# Adjusted top position for car_id 84 (frame 258)
# Adjusted left position for car_id 84 (frame 258)
# Adjusted right position for car_id 84 (frame 258)
# Resized license crop for car_id 84 (frame 258)
# Adjusted top position for car_id 84 (frame 259)
# Adjusted left position for car_id 84 (frame 259)
# Adjusted right position for car_id 84 (frame 259)
# Resized license crop for car_id 84 (frame 259)
# Adjusted top position for car_id 84 (frame 260)
# Adjusted left position for car_id 84 (frame 260)
# Adjusted right position for car_id 84 (frame 260)
# Resized license crop for car_id 84 (frame 260)
# Adjusted top position for car_id 84 (frame 261)
# Adjusted left position for car_id 84 (frame 261)
# Adjusted right position for car_id 84 (frame 261)
# Resized license crop for car_id 84 (frame 261)
# Adjusted top position for car_id 84 (frame 262)
# Adjusted left position for car_id 84 (frame 262)
# Adjusted right position for car_id 84 (frame 262)
# Resized license crop for car_id 84 (frame 262)
# Adjusted top position for car_id 84 (frame 263)
# Adjusted left position for car_id 84 (frame 263)
# Adjusted right position for car_id 84 (frame 263)
# Resized license crop for car_id 84 (frame 263)
# Adjusted top position for car_id 84 (frame 264)
# Adjusted left position for car_id 84 (frame 264)
# Adjusted right position for car_id 84 (frame 264)
# Resized license crop for car_id 84 (frame 264)
# Adjusted top position for car_id 84 (frame 265)
# Adjusted left position for car_id 84 (frame 265)
# Adjusted right position for car_id 84 (frame 265)
# Resized license crop for car_id 84 (frame 265)
# Adjusted top position for car_id 84 (frame 266)
# Adjusted left position for car_id 84 (frame 266)
# Adjusted right position for car_id 84 (frame 266)
# Resized license crop for car_id 84 (frame 266)
# Adjusted top position for car_id 84 (frame 267)
# Adjusted left position for car_id 84 (frame 267)
# Adjusted right position for car_id 84 (frame 267)
# Resized license crop for car_id 84 (frame 267)
# Adjusted top position for car_id 84 (frame 268)
# Adjusted left position for car_id 84 (frame 268)
# Adjusted right position for car_id 84 (frame 268)
# Resized license crop for car_id 84 (frame 268)
# Adjusted top position for car_id 84 (frame 269)
# Adjusted left position for car_id 84 (frame 269)
# Adjusted right position for car_id 84 (frame 269)
# Resized license crop for car_id 84 (frame 269)
# Adjusted top position for car_id 84 (frame 270)
# Adjusted left position for car_id 84 (frame 270)
# Adjusted right position for car_id 84 (frame 270)
# Resized license crop for car_id 84 (frame 270)
# Adjusted top position for car_id 84 (frame 271)
# Adjusted left position for car_id 84 (frame 271)
# Adjusted right position for car_id 84 (frame 271)
# Resized license crop for car_id 84 (frame 271)
# Adjusted top position for car_id 84 (frame 272)
# Adjusted left position for car_id 84 (frame 272)
# Adjusted right position for car_id 84 (frame 272)
# Resized license crop for car_id 84 (frame 272)
# Adjusted top position for car_id 84 (frame 273)
# Adjusted left position for car_id 84 (frame 273)
# Adjusted right position for car_id 84 (frame 273)
# Resized license crop for car_id 84 (frame 273)
# Adjusted top position for car_id 84 (frame 274)
# Adjusted left position for car_id 84 (frame 274)
# Adjusted right position for car_id 84 (frame 274)
# Resized license crop for car_id 84 (frame 274)
# Adjusted top position for car_id 84 (frame 275)
# Adjusted left position for car_id 84 (frame 275)
# Adjusted right position for car_id 84 (frame 275)
# Resized license crop for car_id 84 (frame 275)
# Adjusted top position for car_id 84 (frame 276)
# Adjusted left position for car_id 84 (frame 276)
# Adjusted right position for car_id 84 (frame 276)
# Resized license crop for car_id 84 (frame 276)
# Adjusted top position for car_id 84 (frame 277)
# Adjusted left position for car_id 84 (frame 277)
# Adjusted right position for car_id 84 (frame 277)
# Resized license crop for car_id 84 (frame 277)
# Adjusted top position for car_id 84 (frame 278)
# Adjusted left position for car_id 84 (frame 278)
# Adjusted right position for car_id 84 (frame 278)
# Resized license crop for car_id 84 (frame 278)
# Adjusted top position for car_id 84 (frame 279)
# Adjusted left position for car_id 84 (frame 279)
# Adjusted right position for car_id 84 (frame 279)
# Resized license crop for car_id 84 (frame 279)
# Adjusted top position for car_id 84 (frame 280)
# Adjusted left position for car_id 84 (frame 280)
# Adjusted right position for car_id 84 (frame 280)
# Resized license crop for car_id 84 (frame 280)
# Adjusted top position for car_id 84 (frame 281)
# Adjusted left position for car_id 84 (frame 281)
# Adjusted right position for car_id 84 (frame 281)
# Resized license crop for car_id 84 (frame 281)
# Adjusted top position for car_id 84 (frame 282)
# Adjusted left position for car_id 84 (frame 282)
# Adjusted right position for car_id 84 (frame 282)
# Resized license crop for car_id 84 (frame 282)
# Adjusted top position for car_id 84 (frame 283)
# Adjusted left position for car_id 84 (frame 283)
# Adjusted right position for car_id 84 (frame 283)
# Resized license crop for car_id 84 (frame 283)
# Adjusted top position for car_id 84 (frame 284)
# Adjusted left position for car_id 84 (frame 284)
# Adjusted right position for car_id 84 (frame 284)
# Resized license crop for car_id 84 (frame 284)
# Adjusted top position for car_id 84 (frame 285)
# Adjusted left position for car_id 84 (frame 285)
# Adjusted right position for car_id 84 (frame 285)
# Resized license crop for car_id 84 (frame 285)
# Adjusted top position for car_id 84 (frame 286)
# Adjusted left position for car_id 84 (frame 286)
# Adjusted right position for car_id 84 (frame 286)
# Resized license crop for car_id 84 (frame 286)
# Adjusted top position for car_id 84 (frame 287)
# Adjusted left position for car_id 84 (frame 287)
# Adjusted right position for car_id 84 (frame 287)
# Resized license crop for car_id 84 (frame 287)
# Adjusted top position for car_id 84 (frame 288)
# Adjusted left position for car_id 84 (frame 288)
# Adjusted right position for car_id 84 (frame 288)
# Resized license crop for car_id 84 (frame 288)
# Adjusted top position for car_id 84 (frame 289)
# Adjusted left position for car_id 84 (frame 289)
# Adjusted right position for car_id 84 (frame 289)
# Resized license crop for car_id 84 (frame 289)
# Adjusted top position for car_id 84 (frame 290)
# Adjusted left position for car_id 84 (frame 290)
# Adjusted right position for car_id 84 (frame 290)
# Resized license crop for car_id 84 (frame 290)
# Adjusted top position for car_id 84 (frame 291)
# Adjusted left position for car_id 84 (frame 291)
# Adjusted right position for car_id 84 (frame 291)
# Resized license crop for car_id 84 (frame 291)
# Adjusted top position for car_id 84 (frame 292)
# Adjusted left position for car_id 84 (frame 292)
# Adjusted right position for car_id 84 (frame 292)
# Resized license crop for car_id 84 (frame 292)
# Adjusted top position for car_id 84 (frame 293)
# Adjusted left position for car_id 84 (frame 293)
# Adjusted right position for car_id 84 (frame 293)
# Resized license crop for car_id 84 (frame 293)
# Adjusted top position for car_id 84 (frame 294)
# Adjusted left position for car_id 84 (frame 294)
# Adjusted right position for car_id 84 (frame 294)
# Resized license crop for car_id 84 (frame 294)
# Adjusted top position for car_id 84 (frame 295)
# Adjusted left position for car_id 84 (frame 295)
# Adjusted right position for car_id 84 (frame 295)
# Resized license crop for car_id 84 (frame 295)
# Adjusted top position for car_id 84 (frame 296)
# Adjusted left position for car_id 84 (frame 296)
# Adjusted right position for car_id 84 (frame 296)
# Resized license crop for car_id 84 (frame 296)
# Adjusted top position for car_id 84 (frame 297)
# Adjusted left position for car_id 84 (frame 297)
# Adjusted right position for car_id 84 (frame 297)
# Resized license crop for car_id 84 (frame 297)
# Adjusted top position for car_id 84 (frame 298)
# Adjusted left position for car_id 84 (frame 298)
# Adjusted right position for car_id 84 (frame 298)
# Resized license crop for car_id 84 (frame 298)
# Adjusted top position for car_id 84 (frame 299)
# Adjusted left position for car_id 84 (frame 299)
# Adjusted right position for car_id 84 (frame 299)
# Resized license crop for car_id 84 (frame 299)
# Adjusted top position for car_id 84 (frame 300)
# Adjusted left position for car_id 84 (frame 300)
# Adjusted right position for car_id 84 (frame 300)
# Resized license crop for car_id 84 (frame 300)
# Adjusted top position for car_id 84 (frame 301)
# Adjusted left position for car_id 84 (frame 301)
# Adjusted right position for car_id 84 (frame 301)
# Resized license crop for car_id 84 (frame 301)
# Adjusted top position for car_id 84 (frame 302)
# Adjusted left position for car_id 84 (frame 302)
# Adjusted right position for car_id 84 (frame 302)
# Resized license crop for car_id 84 (frame 302)
# Adjusted top position for car_id 84 (frame 303)
# Adjusted left position for car_id 84 (frame 303)
# Adjusted right position for car_id 84 (frame 303)
# Resized license crop for car_id 84 (frame 303)
# Adjusted top position for car_id 84 (frame 304)
# Adjusted left position for car_id 84 (frame 304)
# Adjusted right position for car_id 84 (frame 304)
# Resized license crop for car_id 84 (frame 304)
# Adjusted top position for car_id 84 (frame 305)
# Adjusted left position for car_id 84 (frame 305)
# Adjusted right position for car_id 84 (frame 305)
# Resized license crop for car_id 84 (frame 305)
# Adjusted top position for car_id 84 (frame 306)
# Adjusted left position for car_id 84 (frame 306)
# Adjusted right position for car_id 84 (frame 306)
# Resized license crop for car_id 84 (frame 306)
# Adjusted top position for car_id 84 (frame 307)
# Adjusted left position for car_id 84 (frame 307)
# Adjusted right position for car_id 84 (frame 307)
# Resized license crop for car_id 84 (frame 307)
# Adjusted top position for car_id 84 (frame 308)
# Adjusted left position for car_id 84 (frame 308)
# Adjusted right position for car_id 84 (frame 308)
# Resized license crop for car_id 84 (frame 308)
# Adjusted top position for car_id 84 (frame 309)
# Adjusted left position for car_id 84 (frame 309)
# Adjusted right position for car_id 84 (frame 309)
# Resized license crop for car_id 84 (frame 309)
# Adjusted top position for car_id 84 (frame 310)
# Adjusted left position for car_id 84 (frame 310)
# Adjusted right position for car_id 84 (frame 310)
# Resized license crop for car_id 84 (frame 310)
# Adjusted top position for car_id 84 (frame 311)
# Adjusted left position for car_id 84 (frame 311)
# Adjusted right position for car_id 84 (frame 311)
# Resized license crop for car_id 84 (frame 311)
# Adjusted top position for car_id 84 (frame 312)
# Adjusted left position for car_id 84 (frame 312)
# Adjusted right position for car_id 84 (frame 312)
# Resized license crop for car_id 84 (frame 312)
# Adjusted top position for car_id 84 (frame 313)
# Adjusted left position for car_id 84 (frame 313)
# Adjusted right position for car_id 84 (frame 313)
# Resized license crop for car_id 84 (frame 313)
# Adjusted top position for car_id 84 (frame 314)
# Adjusted left position for car_id 84 (frame 314)
# Adjusted right position for car_id 84 (frame 314)
# Resized license crop for car_id 84 (frame 314)
# Adjusted top position for car_id 84 (frame 315)
# Adjusted left position for car_id 84 (frame 315)
# Adjusted right position for car_id 84 (frame 315)
# Resized license crop for car_id 84 (frame 315)
# Adjusted top position for car_id 84 (frame 316)
# Adjusted left position for car_id 84 (frame 316)
# Adjusted right position for car_id 84 (frame 316)
# Resized license crop for car_id 84 (frame 316)
# Adjusted top position for car_id 84 (frame 317)
# Adjusted left position for car_id 84 (frame 317)
# Adjusted right position for car_id 84 (frame 317)
# Resized license crop for car_id 84 (frame 317)
# Adjusted top position for car_id 84 (frame 318)
# Adjusted left position for car_id 84 (frame 318)
# Adjusted right position for car_id 84 (frame 318)
# Resized license crop for car_id 84 (frame 318)
# Adjusted top position for car_id 84 (frame 319)
# Adjusted left position for car_id 84 (frame 319)
# Adjusted right position for car_id 84 (frame 372)
# Resized license crop for car_id 84 (frame 372)
# Adjusted top position for car_id 84 (frame 373)
# Adjusted left position for car_id 84 (frame 373)
# Adjusted right position for car_id 84 (frame 373)
# Resized license crop for car_id 84 (frame 373)
# Adjusted top position for car_id 84 (frame 374)
# Adjusted left position for car_id 84 (frame 374)
# Adjusted right position for car_id 84 (frame 374)
# Resized license crop for car_id 84 (frame 374)
# Adjusted top position for car_id 84 (frame 375)
# Adjusted left position for car_id 84 (frame 375)
# Adjusted right position for car_id 84 (frame 375)
# Resized license crop for car_id 84 (frame 375)
# Adjusted top position for car_id 84 (frame 376)
# Adjusted left position for car_id 84 (frame 376)
# Adjusted right position for car_id 84 (frame 376)
# Resized license crop for car_id 84 (frame 376)
# Adjusted top position for car_id 84 (frame 377)
# Adjusted left position for car_id 84 (frame 377)
# Adjusted right position for car_id 84 (frame 377)
# Resized license crop for car_id 84 (frame 377)
# Adjusted top position for car_id 84 (frame 378)
# Adjusted left position for car_id 84 (frame 378)
# Adjusted right position for car_id 84 (frame 378)
# Resized license crop for car_id 84 (frame 378)
# Adjusted top position for car_id 84 (frame 379)
# Adjusted left position for car_id 84 (frame 379)
# Adjusted right position for car_id 84 (frame 379)
# Resized license crop for car_id 84 (frame 379)
# Adjusted top position for car_id 84 (frame 380)
# Adjusted left position for car_id 84 (frame 380)
# Adjusted right position for car_id 84 (frame 380)
# Resized license crop for car_id 84 (frame 380)
# Adjusted top position for car_id 84 (frame 381)
# Adjusted left position for car_id 84 (frame 381)
# Adjusted right position for car_id 84 (frame 381)
# Resized license crop for car_id 84 (frame 381)
# Adjusted top position for car_id 84 (frame 382)
# Adjusted left position for car_id 84 (frame 382)
# Adjusted right position for car_id 84 (frame 382)
# Resized license crop for car_id 84 (frame 382)
# Adjusted top position for car_id 84 (frame 383)
# Adjusted left position for car_id 84 (frame 383)
# Adjusted right position for car_id 84 (frame 383)
# Resized license crop for car_id 84 (frame 383)
# Adjusted top position for car_id 84 (frame 384)
# Adjusted left position for car_id 84 (frame 384)
# Adjusted right position for car_id 84 (frame 384)
# Resized license crop for car_id 84 (frame 384)
# Adjusted top position for car_id 84 (frame 385)
# Adjusted left position for car_id 84 (frame 385)
# Adjusted right position for car_id 84 (frame 385)
# Resized license crop for car_id 84 (frame 385)
# Adjusted top position for car_id 84 (frame 386)
# Adjusted left position for car_id 84 (frame 386)
# Adjusted right position for car_id 84 (frame 386)
# Resized license crop for car_id 84 (frame 386)
# Adjusted top position for car_id 84 (frame 387)
# Adjusted left position for car_id 84 (frame 387)
# Adjusted right position for car_id 84 (frame 387)
# Resized license crop for car_id 84 (frame 387)
# Adjusted top position for car_id 84 (frame 388)
# Adjusted left position for car_id 84 (frame 388)
# Adjusted right position for car_id 84 (frame 388)
# Resized license crop for car_id 84 (frame 388)
# Adjusted top position for car_id 84 (frame 389)
# Adjusted left position for car_id 84 (frame 389)
# Adjusted right position for car_id 84 (frame 389)
# Resized license crop for car_id 84 (frame 389)
# Resized license crop for car_id 84 (frame 407)
# Adjusted top position for car_id 84 (frame 408)
# Adjusted left position for car_id 84 (frame 408)
# Adjusted right position for car_id 84 (frame 408)
# Resized license crop for car_id 84 (frame 408)
# Adjusted top position for car_id 84 (frame 409)
# Adjusted left position for car_id 84 (frame 409)
# Adjusted right position for car_id 84 (frame 409)
# Resized license crop for car_id 84 (frame 409)
# Adjusted top position for car_id 84 (frame 410)
# Adjusted left position for car_id 84 (frame 410)
# Adjusted right position for car_id 84 (frame 410)
# Resized license crop for car_id 84 (frame 410)
# Adjusted top position for car_id 84 (frame 411)
# Adjusted left position for car_id 84 (frame 411)
# Adjusted right position for car_id 84 (frame 411)
# Resized license crop for car_id 84 (frame 411)
# Adjusted top position for car_id 84 (frame 412)
# Adjusted left position for car_id 84 (frame 412)
# Adjusted right position for car_id 84 (frame 412)
# Resized license crop for car_id 84 (frame 412)
# Adjusted top position for car_id 84 (frame 413)
# Adjusted left position for car_id 84 (frame 413)
# Adjusted right position for car_id 84 (frame 413)
# Resized license crop for car_id 84 (frame 413)
# Adjusted top position for car_id 84 (frame 414)
# Adjusted left position for car_id 84 (frame 414)
# Adjusted right position for car_id 84 (frame 414)
# Resized license crop for car_id 84 (frame 414)
# Adjusted top position for car_id 84 (frame 415)
# Adjusted left position for car_id 84 (frame 415)
# Adjusted right position for car_id 84 (frame 415)
# Resized license crop for car_id 84 (frame 415)
# Adjusted top position for car_id 84 (frame 416)
# Adjusted left position for car_id 84 (frame 416)
# Adjusted right position for car_id 84 (frame 416)
# Resized license crop for car_id 84 (frame 416)
# Adjusted top position for car_id 84 (frame 417)
# Adjusted left position for car_id 84 (frame 417)
# Adjusted right position for car_id 84 (frame 417)
# Resized license crop for car_id 84 (frame 417)
# Adjusted top position for car_id 84 (frame 418)
# Adjusted left position for car_id 84 (frame 418)
# Adjusted right position for car_id 84 (frame 418)
# Resized license crop for car_id 84 (frame 418)
# Adjusted top position for car_id 84 (frame 419)
# Adjusted left position for car_id 84 (frame 419)
# Adjusted right position for car_id 84 (frame 419)
# Resized license crop for car_id 84 (frame 419)
# Adjusted top position for car_id 84 (frame 420)
# Adjusted left position for car_id 84 (frame 420)
# Adjusted right position for car_id 84 (frame 420)
# Resized license crop for car_id 84 (frame 420)
# Adjusted top position for car_id 84 (frame 421)
# Adjusted left position for car_id 84 (frame 421)
# Adjusted right position for car_id 84 (frame 421)
# Resized license crop for car_id 84 (frame 421)
# Adjusted top position for car_id 84 (frame 422)
# Adjusted left position for car_id 84 (frame 422)
# Adjusted right position for car_id 84 (frame 422)
# Resized license crop for car_id 84 (frame 422)
# Adjusted top position for car_id 84 (frame 423)
# Adjusted left position for car_id 84 (frame 423)
# Adjusted right position for car_id 84 (frame 423)
# Resized license crop for car_id 84 (frame 423)
# Adjusted top position for car_id 84 (frame 424)
# Adjusted left position for car_id 84 (frame 424)
# Adjusted right position for car_id 84 (frame 424)
# Resized license crop for car_id 84 (frame 424)
# Adjusted top position for car_id 84 (frame 425)
# Adjusted left position for car_id 84 (frame 425)
# Adjusted right position for car_id 84 (frame 425)
# Resized license crop for car_id 84 (frame 425)
# Adjusted top position for car_id 84 (frame 426)
# Adjusted left position for car_id 84 (frame 426)
# Adjusted right position for car_id 84 (frame 426)
# Resized license crop for car_id 84 (frame 426)
# Adjusted top position for car_id 84 (frame 427)
# Adjusted left position for car_id 84 (frame 427)
# Adjusted right position for car_id 84 (frame 427)
# Resized license crop for car_id 84 (frame 427)
# Adjusted top position for car_id 84 (frame 428)
# Adjusted left position for car_id 84 (frame 428)
# Adjusted right position for car_id 84 (frame 428)
# Resized license crop for car_id 84 (frame 428)
# Adjusted top position for car_id 84 (frame 429)
# Adjusted left position for car_id 84 (frame 429)
# Adjusted right position for car_id 84 (frame 429)
# Resized license crop for car_id 84 (frame 429)
# Adjusted top position for car_id 84 (frame 430)
# Adjusted left position for car_id 84 (frame 430)
# Adjusted right position for car_id 84 (frame 430)
# Resized license crop for car_id 84 (frame 430)
# Adjusted top position for car_id 84 (frame 431)
# Adjusted left position for car_id 84 (frame 431)
# Adjusted right position for car_id 84 (frame 431)
# Resized license crop for car_id 84 (frame 431)
# Adjusted top position for car_id 84 (frame 432)
# Adjusted left position for car_id 84 (frame 432)
# Adjusted right position for car_id 84 (frame 432)
# Resized license crop for car_id 84 (frame 432)
# Adjusted top position for car_id 84 (frame 433)
# Adjusted left position for car_id 84 (frame 433)
# Adjusted right position for car_id 84 (frame 433)
# Resized license crop for car_id 84 (frame 433)
# Adjusted top position for car_id 84 (frame 434)
# Adjusted left position for car_id 84 (frame 434)
# Adjusted right position for car_id 84 (frame 434)
# Resized license crop for car_id 84 (frame 434)
# Adjusted top position for car_id 84 (frame 435)
# Adjusted left position for car_id 84 (frame 435)
# Adjusted right position for car_id 84 (frame 435)
# Resized license crop for car_id 84 (frame 435)
# Adjusted top position for car_id 84 (frame 436)
# Adjusted left position for car_id 84 (frame 436)
# Adjusted right position for car_id 84 (frame 436)
# Resized license crop for car_id 84 (frame 436)
# Adjusted top position for car_id 84 (frame 437)
# Adjusted left position for car_id 84 (frame 437)
# Adjusted right position for car_id 84 (frame 437)
# Resized license crop for car_id 84 (frame 437)
# Adjusted top position for car_id 84 (frame 438)
# Adjusted left position for car_id 84 (frame 438)
# Adjusted right position for car_id 84 (frame 438)
# Resized license crop for car_id 84 (frame 438)
# Adjusted top position for car_id 84 (frame 439)
# Adjusted left position for car_id 84 (frame 439)
# Adjusted right position for car_id 84 (frame 439)
# Resized license crop for car_id 84 (frame 439)
# Adjusted top position for car_id 84 (frame 440)
# Adjusted left position for car_id 84 (frame 440)
# Adjusted right position for car_id 84 (frame 440)
# Resized license crop for car_id 84 (frame 440)
# Adjusted top position for car_id 84 (frame 441)
# Adjusted left position for car_id 84 (frame 441)
# Adjusted right position for car_id 84 (frame 441)
# Resized license crop for car_id 84 (frame 441)
# Adjusted top position for car_id 84 (frame 442)
# Adjusted left position for car_id 84 (frame 442)
# Adjusted right position for car_id 84 (frame 442)
# Resized license crop for car_id 84 (frame 442)
# Adjusted top position for car_id 84 (frame 443)
# Adjusted left position for car_id 84 (frame 443)
# Adjusted right position for car_id 84 (frame 443)
# Resized license crop for car_id 84 (frame 443)
# Adjusted top position for car_id 84 (frame 444)
# Adjusted left position for car_id 84 (frame 444)
# Adjusted right position for car_id 84 (frame 444)
# Resized license crop for car_id 84 (frame 444)
# Adjusted top position for car_id 84 (frame 445)
# Adjusted left position for car_id 84 (frame 445)
# Adjusted right position for car_id 84 (frame 445)
# Resized license crop for car_id 84 (frame 445)
# Adjusted top position for car_id 84 (frame 446)
# Adjusted left position for car_id 84 (frame 446)
# Adjusted right position for car_id 84 (frame 446)
# Resized license crop for car_id 84 (frame 446)
# Adjusted top position for car_id 84 (frame 447)
# Adjusted left position for car_id 84 (frame 447)
# Adjusted right position for car_id 84 (frame 447)
# Resized license crop for car_id 84 (frame 447)
# Adjusted top position for car_id 84 (frame 448)
# Adjusted left position for car_id 84 (frame 448)
# Adjusted right position for car_id 84 (frame 448)
# Resized license crop for car_id 84 (frame 448)
# Adjusted top position for car_id 84 (frame 449)
# Adjusted left position for car_id 84 (frame 449)
# Adjusted right position for car_id 84 (frame 449)
# Resized license crop for car_id 84 (frame 449)
# Adjusted top position for car_id 84 (frame 450)
# Adjusted left position for car_id 84 (frame 450)
# Adjusted right position for car_id 84 (frame 450)
# Resized license crop for car_id 84 (frame 450)
# Adjusted top position for car_id 84 (frame 451)
# Adjusted left position for car_id 84 (frame 451)
# Adjusted right position for car_id 84 (frame 451)
# Resized license crop for car_id 84 (frame 451)
# Adjusted top position for car_id 84 (frame 452)
# Adjusted left position for car_id 84 (frame 452)
# Adjusted right position for car_id 84 (frame 452)
# Resized license crop for car_id 84 (frame 452)
# Adjusted top position for car_id 84 (frame 453)
# Adjusted left position for car_id 84 (frame 453)
# Adjusted right position for car_id 84 (frame 453)
# Resized license crop for car_id 84 (frame 453)
# Adjusted top position for car_id 84 (frame 454)
# Adjusted left position for car_id 84 (frame 454)
# Adjusted right position for car_id 84 (frame 454)
# Resized license crop for car_id 84 (frame 454)
# Adjusted top position for car_id 84 (frame 455)
# Adjusted left position for car_id 84 (frame 455)
# Adjusted right position for car_id 84 (frame 455)
# Resized license crop for car_id 84 (frame 455)
# Adjusted top position for car_id 84 (frame 456)
# Adjusted left position for car_id 84 (frame 456)
# Adjusted right position for car_id 84 (frame 456)
# Resized license crop for car_id 84 (frame 456)
# Adjusted top position for car_id 84 (frame 457)
# Adjusted left position for car_id 84 (frame 457)
# Adjusted right position for car_id 84 (frame 457)
# Resized license crop for car_id 84 (frame 457)
# Adjusted top position for car_id 84 (frame 458)
# Adjusted left position for car_id 84 (frame 458)
# Adjusted right position for car_id 84 (frame 458)
# Resized license crop for car_id 84 (frame 458)
# Adjusted top position for car_id 84 (frame 459)
# Adjusted left position for car_id 84 (frame 459)
# Adjusted right position for car_id 84 (frame 459)
# Resized license crop for car_id 84 (frame 459)
# Adjusted top position for car_id 84 (frame 460)
# Adjusted left position for car_id 84 (frame 460)
# Adjusted right position for car_id 84 (frame 460)
# Adjusted left position for car_id 84 (frame 478)
# Adjusted right position for car_id 84 (frame 478)
# Resized license crop for car_id 84 (frame 478)
# Adjusted top position for car_id 84 (frame 479)
# Adjusted left position for car_id 84 (frame 479)
# Adjusted right position for car_id 84 (frame 479)
# Resized license crop for car_id 84 (frame 479)
# Adjusted top position for car_id 84 (frame 480)
# Adjusted left position for car_id 84 (frame 480)
# Adjusted right position for car_id 84 (frame 480)
# Resized license crop for car_id 84 (frame 480)
# Adjusted top position for car_id 84 (frame 481)
# Adjusted left position for car_id 84 (frame 481)
# Adjusted right position for car_id 84 (frame 481)
# Resized license crop for car_id 84 (frame 481)
# Adjusted top position for car_id 84 (frame 482)
# Adjusted left position for car_id 84 (frame 482)
# Adjusted right position for car_id 84 (frame 482)
# Resized license crop for car_id 84 (frame 482)
# Adjusted top position for car_id 84 (frame 483)
# Adjusted left position for car_id 84 (frame 483)
# Adjusted right position for car_id 84 (frame 483)
# Resized license crop for car_id 84 (frame 483)
# Adjusted top position for car_id 84 (frame 484)
# Adjusted left position for car_id 84 (frame 484)
# Adjusted right position for car_id 84 (frame 484)
# Resized license crop for car_id 84 (frame 484)
# Adjusted top position for car_id 84 (frame 485)
# ...
# Resized license crop for car_id 84 (frame 538)
# Adjusted top position for car_id 84 (frame 539)
# Adjusted left position for car_id 84 (frame 539)
# Adjusted right position for car_id 84 (frame 539)
# Resized license crop for car_id 84 (frame 539)
# Adjusted top position for car_id 84 (frame 540)
# Adjusted left position for car_id 84 (frame 540)
# Adjusted right position for car_id 84 (frame 540)
# Resized license crop for car_id 84 (frame 540)
# Adjusted top position for car_id 84 (frame 541)
# Adjusted left position for car_id 84 (frame 541)
# Adjusted right position for car_id 84 (frame 541)
# Resized license crop for car_id 84 (frame 541)
# Adjusted top position for car_id 84 (frame 542)
# Adjusted left position for car_id 84 (frame 542)
# Adjusted right position for car_id 84 (frame 542)
# Resized license crop for car_id 84 (frame 542)
# Adjusted top position for car_id 84 (frame 543)
# Adjusted left position for car_id 84 (frame 543)
# Adjusted right position for car_id 84 (frame 543)
# Resized license crop for car_id 84 (frame 543)
# Adjusted top position for car_id 84 (frame 544)
# Adjusted left position for car_id 84 (frame 544)
# Adjusted right position for car_id 84 (frame 544)
# Resized license crop for car_id 84 (frame 544)
# Adjusted top position for car_id 84 (frame 545)
# Adjusted left position for car_id 84 (frame 545)
# Adjusted right position for car_id 84 (frame 545)
# Resized license crop for car_id 84 (frame 545)
# Adjusted top position for car_id 84 (frame 546)
# Adjusted left position for car_id 84 (frame 546)
# Adjusted right position for car_id 84 (frame 546)
# Resized license crop for car_id 84 (frame 546)
# Adjusted top position for car_id 84 (frame 547)
# Adjusted left position for car_id 84 (frame 547)
# Adjusted right position for car_id 84 (frame 547)
# Resized license crop for car_id 84 (frame 547)
# Adjusted top position for car_id 84 (frame 548)
# Adjusted left position for car_id 84 (frame 548)
# Adjusted right position for car_id 84 (frame 548)
# Resized license crop for car_id 84 (frame 548)
# Adjusted top position for car_id 84 (frame 549)
# Adjusted left position for car_id 84 (frame 549)
# Adjusted right position for car_id 84 (frame 549)
# Resized license crop for car_id 84 (frame 549)
# Adjusted top position for car_id 84 (frame 550)
# Adjusted left position for car_id 84 (frame 550)
# Adjusted right position for car_id 84 (frame 550)
# Resized license crop for car_id 84 (frame 550)
# Adjusted top position for car_id 84 (frame 551)
# Adjusted left position for car_id 84 (frame 551)
# Adjusted right position for car_id 84 (frame 551)
# Resized license crop for car_id 84 (frame 551)
# Adjusted top position for car_id 84 (frame 552)
# Adjusted left position for car_id 84 (frame 552)
# Adjusted right position for car_id 84 (frame 552)
# Resized license crop for car_id 84 (frame 552)
# Adjusted top position for car_id 84 (frame 553)
# Adjusted left position for car_id 84 (frame 553)
# Adjusted right position for car_id 84 (frame 553)
# Resized license crop for car_id 84 (frame 553)
# Adjusted top position for car_id 84 (frame 554)
# Adjusted left position for car_id 84 (frame 554)
# Adjusted right position for car_id 84 (frame 554)
# Resized license crop for car_id 84 (frame 554)
# Adjusted top position for car_id 84 (frame 555)
# Adjusted left position for car_id 84 (frame 555)
# Adjusted right position for car_id 84 (frame 555)
# Resized license crop for car_id 84 (frame 555)
# Adjusted top position for car_id 84 (frame 556)
# Adjusted left position for car_id 84 (frame 556)
# Adjusted right position for car_id 84 (frame 556)
# Resized license crop for car_id 84 (frame 556)
# Adjusted top position for car_id 84 (frame 557)
# Adjusted left position for car_id 84 (frame 557)
# Adjusted right position for car_id 84 (frame 557)
# Resized license crop for car_id 84 (frame 557)
# Adjusted top position for car_id 84 (frame 558)
# Adjusted left position for car_id 84 (frame 558)
# Adjusted right position for car_id 84 (frame 558)
# Resized license crop for car_id 84 (frame 558)
# Adjusted top position for car_id 84 (frame 559)
# Adjusted left position for car_id 84 (frame 559)
# Adjusted right position for car_id 84 (frame 559)
# Resized license crop for car_id 84 (frame 559)
# Adjusted top position for car_id 84 (frame 560)
# Adjusted left position for car_id 84 (frame 560)
# Adjusted right position for car_id 84 (frame 560)
# Resized license crop for car_id 84 (frame 560)
# Adjusted top position for car_id 84 (frame 561)
# Adjusted left position for car_id 84 (frame 561)
# Adjusted right position for car_id 84 (frame 561)
# Resized license crop for car_id 84 (frame 561)
# Adjusted top position for car_id 84 (frame 562)
# Adjusted left position for car_id 84 (frame 562)
# Adjusted right position for car_id 84 (frame 562)
# Resized license crop for car_id 84 (frame 562)
# Adjusted top position for car_id 84 (frame 563)
# Adjusted left position for car_id 84 (frame 563)
# Adjusted right position for car_id 84 (frame 563)
# Resized license crop for car_id 84 (frame 563)
# Adjusted top position for car_id 84 (frame 564)
# Adjusted left position for car_id 84 (frame 564)
# Adjusted right position for car_id 84 (frame 564)
# Resized license crop for car_id 84 (frame 564)
# Adjusted top position for car_id 84 (frame 565)
# Adjusted left position for car_id 84 (frame 565)
# Adjusted right position for car_id 84 (frame 565)
# Resized license crop for car_id 84 (frame 565)
# Adjusted top position for car_id 84 (frame 566)
# Adjusted left position for car_id 84 (frame 566)
# Adjusted right position for car_id 84 (frame 566)
# Resized license crop for car_id 84 (frame 566)
# Adjusted top position for car_id 84 (frame 567)
# Adjusted left position for car_id 84 (frame 567)
# Adjusted right position for car_id 84 (frame 567)
# Resized license crop for car_id 84 (frame 567)
# Adjusted top position for car_id 84 (frame 568)
# Adjusted left position for car_id 84 (frame 568)
# Adjusted right position for car_id 84 (frame 568)
# Resized license crop for car_id 84 (frame 568)
# Adjusted top position for car_id 84 (frame 569)
# Adjusted left position for car_id 84 (frame 569)
# Adjusted right position for car_id 84 (frame 569)
# Resized license crop for car_id 84 (frame 569)
# Adjusted top position for car_id 84 (frame 570)
# Adjusted left position for car_id 84 (frame 570)
# Adjusted right position for car_id 84 (frame 570)
# Resized license crop for car_id 84 (frame 570)
# Adjusted top position for car_id 84 (frame 571)
# Adjusted left position for car_id 84 (frame 571)
# Adjusted right position for car_id 84 (frame 571)
# Resized license crop for car_id 84 (frame 571)
# Adjusted top position for car_id 84 (frame 572)
# Adjusted left position for car_id 84 (frame 572)
# Adjusted right position for car_id 84 (frame 572)
# Resized license crop for car_id 84 (frame 572)
# Adjusted top position for car_id 84 (frame 573)
# Adjusted left position for car_id 84 (frame 573)
# Adjusted right position for car_id 84 (frame 573)
# Resized license crop for car_id 84 (frame 573)
# Adjusted top position for car_id 84 (frame 574)
# Adjusted left position for car_id 84 (frame 574)
# Adjusted right position for car_id 84 (frame 574)
# Resized license crop for car_id 84 (frame 574)
# Adjusted top position for car_id 84 (frame 575)
# Adjusted left position for car_id 84 (frame 575)
# Adjusted right position for car_id 84 (frame 575)
# Resized license crop for car_id 84 (frame 575)
# Adjusted top position for car_id 84 (frame 576)
# Adjusted left position for car_id 84 (frame 576)
# Adjusted right position for car_id 84 (frame 576)
# Resized license crop for car_id 84 (frame 576)
# Adjusted top position for car_id 84 (frame 577)
# Adjusted left position for car_id 84 (frame 577)
# Adjusted right position for car_id 84 (frame 577)
# Resized license crop for car_id 84 (frame 577)
# Adjusted top position for car_id 84 (frame 578)
# Adjusted left position for car_id 84 (frame 578)
# Adjusted right position for car_id 84 (frame 578)
# Resized license crop for car_id 84 (frame 578)
# Adjusted top position for car_id 84 (frame 579)
# Adjusted left position for car_id 84 (frame 579)
# Adjusted right position for car_id 84 (frame 579)
# Resized license crop for car_id 84 (frame 579)
# Adjusted top position for car_id 84 (frame 580)
# Adjusted left position for car_id 84 (frame 580)
# Adjusted right position for car_id 84 (frame 580)
# Resized license crop for car_id 84 (frame 580)
# Adjusted top position for car_id 84 (frame 581)
# Adjusted left position for car_id 84 (frame 581)
# Adjusted right position for car_id 84 (frame 581)
# Resized license crop for car_id 84 (frame 581)
# Adjusted top position for car_id 84 (frame 582)
# Adjusted left position for car_id 84 (frame 582)
# Adjusted right position for car_id 84 (frame 582)
# Resized license crop for car_id 84 (frame 582)
# Adjusted top position for car_id 84 (frame 583)
# Adjusted left position for car_id 84 (frame 583)
# Adjusted right position for car_id 84 (frame 583)
# Resized license crop for car_id 84 (frame 583)
# Adjusted top position for car_id 84 (frame 584)
# Adjusted left position for car_id 84 (frame 584)
# Adjusted right position for car_id 84 (frame 584)
# Resized license crop for car_id 84 (frame 584)
# Adjusted top position for car_id 84 (frame 585)
# Adjusted left position for car_id 84 (frame 585)
# Adjusted right position for car_id 84 (frame 585)
# Resized license crop for car_id 84 (frame 585)
# Adjusted top position for car_id 84 (frame 586)
# Adjusted left position for car_id 84 (frame 586)
# Adjusted right position for car_id 84 (frame 586)
# Resized license crop for car_id 84 (frame 586)
# Adjusted top position for car_id 84 (frame 587)
# Adjusted left position for car_id 84 (frame 587)
# Adjusted right position for car_id 84 (frame 587)
# Resized license crop for car_id 84 (frame 587)
# Adjusted top position for car_id 84 (frame 588)
# Adjusted left position for car_id 84 (frame 588)
# Adjusted right position for car_id 84 (frame 588)
# Resized license crop for car_id 84 (frame 588)
# Adjusted top position for car_id 84 (frame 589)
# Adjusted left position for car_id 84 (frame 589)
# Adjusted right position for car_id 84 (frame 589)
# Resized license crop for car_id 84 (frame 589)
# Adjusted top position for car_id 84 (frame 590)
# Adjusted left position for car_id 84 (frame 590)
# Adjusted right position for car_id 84 (frame 590)
# Resized license crop for car_id 84 (frame 590)
# Adjusted top position for car_id 84 (frame 591)
# Adjusted left position for car_id 84 (frame 591)
# Adjusted right position for car_id 84 (frame 591)
# Resized license crop for car_id 84 (frame 591)
# Adjusted top position for car_id 84 (frame 592)
# Adjusted left position for car_id 84 (frame 592)
# Adjusted right position for car_id 84 (frame 592)
# Resized license crop for car_id 84 (frame 592)
# Adjusted top position for car_id 84 (frame 593)
# Adjusted left position for car_id 84 (frame 593)
# Adjusted right position for car_id 84 (frame 593)
# Resized license crop for car_id 84 (frame 593)
# Adjusted top position for car_id 84 (frame 594)
# Adjusted left position for car_id 84 (frame 594)
# Adjusted right position for car_id 84 (frame 594)
# Resized license crop for car_id 84 (frame 594)
# Adjusted top position for car_id 84 (frame 595)
# Adjusted left position for car_id 84 (frame 595)
# Adjusted right position for car_id 84 (frame 595)
# Resized license crop for car_id 84 (frame 595)
# Adjusted top position for car_id 84 (frame 596)
# Adjusted left position for car_id 84 (frame 596)
# Adjusted right position for car_id 84 (frame 596)
# Resized license crop for car_id 84 (frame 596)
# Adjusted top position for car_id 84 (frame 597)
# Adjusted left position for car_id 84 (frame 597)
# Adjusted right position for car_id 84 (frame 597)
# Resized license crop for car_id 84 (frame 597)
# Adjusted top position for car_id 84 (frame 598)
# Adjusted left position for car_id 84 (frame 598)
# Adjusted right position for car_id 84 (frame 598)
# Resized license crop for car_id 84 (frame 598)
# Adjusted top position for car_id 84 (frame 599)
# Adjusted left position for car_id 84 (frame 599)
# Adjusted right position for car_id 84 (frame 599)
# Resized license crop for car_id 84 (frame 599)
# Adjusted top position for car_id 84 (frame 600)
# Adjusted left position for car_id 84 (frame 600)
# Adjusted right position for car_id 84 (frame 600)
# Resized license crop for car_id 84 (frame 600)
# Adjusted top position for car_id 84 (frame 601)
# Adjusted left position for car_id 84 (frame 601)
# Adjusted right position for car_id 84 (frame 601)
# Resized license crop for car_id 84 (frame 601)
# Adjusted top position for car_id 84 (frame 602)
# Adjusted left position for car_id 84 (frame 602)
# Adjusted right position for car_id 84 (frame 602)
# Resized license crop for car_id 84 (frame 602)
# Adjusted top position for car_id 84 (frame 603)
# Adjusted left position for car_id 84 (frame 603)
# Adjusted right position for car_id 84 (frame 603)
# Resized license crop for car_id 84 (frame 603)
# Adjusted top position for car_id 84 (frame 604)
# Adjusted left position for car_id 84 (frame 604)
# Adjusted right position for car_id 84 (frame 604)
# Resized license crop for car_id 84 (frame 604)
# Adjusted top position for car_id 84 (frame 605)
# Adjusted left position for car_id 84 (frame 605)
# Adjusted right position for car_id 84 (frame 605)
# Resized license crop for car_id 84 (frame 605)
# Adjusted top position for car_id 84 (frame 606)
# Adjusted left position for car_id 84 (frame 606)
# Adjusted right position for car_id 84 (frame 606)
# Resized license crop for car_id 84 (frame 606)
# Adjusted top position for car_id 84 (frame 607)
# Adjusted left position for car_id 84 (frame 607)
# Adjusted right position for car_id 84 (frame 607)
# Resized license crop for car_id 84 (frame 607)
# Adjusted top position for car_id 84 (frame 608)
# Adjusted left position for car_id 84 (frame 608)
# Adjusted right position for car_id 84 (frame 608)
# Resized license crop for car_id 84 (frame 608)
# Adjusted top position for car_id 84 (frame 609)
# Adjusted left position for car_id 84 (frame 609)
# Adjusted right position for car_id 84 (frame 609)
# Resized license crop for car_id 84 (frame 609)
# Adjusted top position for car_id 84 (frame 610)
# Adjusted left position for car_id 84 (frame 610)
# Adjusted right position for car_id 84 (frame 610)
# Resized license crop for car_id 84 (frame 610)
# Adjusted top position for car_id 84 (frame 611)
# Adjusted left position for car_id 84 (frame 611)
# Adjusted right position for car_id 84 (frame 611)
# Resized license crop for car_id 84 (frame 611)
# Adjusted top position for car_id 84 (frame 612)
# Adjusted left position for car_id 84 (frame 612)
# Adjusted right position for car_id 84 (frame 612)
# Resized license crop for car_id 84 (frame 612)
# Adjusted top position for car_id 84 (frame 613)
# Adjusted left position for car_id 84 (frame 613)
# Adjusted right position for car_id 84 (frame 613)
# Resized license crop for car_id 84 (frame 613)
# Adjusted top position for car_id 84 (frame 614)
# Adjusted left position for car_id 84 (frame 614)
# Adjusted right position for car_id 84 (frame 614)
# Resized license crop for car_id 84 (frame 614)
# Adjusted top position for car_id 84 (frame 615)
# Adjusted left position for car_id 84 (frame 615)
# Adjusted right position for car_id 84 (frame 615)
# Resized license crop for car_id 84 (frame 615)
# Adjusted top position for car_id 84 (frame 616)
# Adjusted left position for car_id 84 (frame 616)
# Adjusted right position for car_id 84 (frame 616)
# Resized license crop for car_id 84 (frame 616)
# Adjusted top position for car_id 84 (frame 617)
# Adjusted left position for car_id 84 (frame 617)
# Adjusted right position for car_id 84 (frame 617)
# Resized license crop for car_id 84 (frame 617)
# Adjusted top position for car_id 84 (frame 618)
# Adjusted left position for car_id 84 (frame 618)
# Adjusted right position for car_id 84 (frame 618)
# Resized license crop for car_id 84 (frame 618)
# Adjusted top position for car_id 84 (frame 619)
# Adjusted left position for car_id 84 (frame 619)
# Adjusted right position for car_id 84 (frame 619)
# Resized license crop for car_id 84 (frame 619)
# Adjusted top position for car_id 84 (frame 620)
# Adjusted left position for car_id 84 (frame 620)
# Adjusted right position for car_id 84 (frame 620)
# Resized license crop for car_id 84 (frame 620)
# Video processing complete

# %%
import ast
import cv2
import numpy as np
import pandas as pd


def draw_border(img, top_left, bottom_right, color=(0, 255, 0), thickness=10, line_length_x=200, line_length_y=200):
    x1, y1 = top_left
    x2, y2 = bottom_right

    cv2.line(img, (x1, y1), (x1, y1 + line_length_y), color, thickness)  #-- top-left
    cv2.line(img, (x1, y1), (x1 + line_length_x, y1), color, thickness)

    cv2.line(img, (x1, y2), (x1, y2 - line_length_y), color, thickness)  #-- bottom-left
    cv2.line(img, (x1, y2), (x1 + line_length_x, y2), color, thickness)

    cv2.line(img, (x2, y1), (x2 - line_length_x, y1), color, thickness)  #-- top-right
    cv2.line(img, (x2, y1), (x2, y1 + line_length_y), color, thickness)

    cv2.line(img, (x2, y2), (x2, y2 - line_length_y), color, thickness)  #-- bottom-right
    cv2.line(img, (x2, y2), (x2 - line_length_x, y2), color, thickness)

    return img


results = pd.read_csv('./test_interpolated.csv')

# load video
video_path = 'test2.mp4'
cap = cv2.VideoCapture(video_path)

fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Specify the codec
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter('./out.mp4', fourcc, fps, (width, height))

license_plate = {}
for car_id in np.unique(results['car_id']):
    try:
        # Check if license_number_score column exists and has valid data
        if 'license_number_score' not in results.columns or results[results['car_id'] == car_id]['license_number_score'].empty:
            print(f"Warning: No license_number_score for car_id {car_id}")
            continue
            
        max_ = np.amax(results[results['car_id'] == car_id]['license_number_score'])
        
        # Verify we have license number data
        if 'license_number' not in results.columns or results[(results['car_id'] == car_id) & 
                                               (results['license_number_score'] == max_)]['license_number'].empty:
            print(f"Warning: No license_number for car_id {car_id}")
            continue
            
        license_number = results[(results['car_id'] == car_id) & 
                                (results['license_number_score'] == max_)]['license_number'].iloc[0]
        
        license_plate[car_id] = {
            'license_plate_number': license_number
        }
    except Exception as e:
        print(f"Error processing car_id {car_id}: {e}")


frame_nmr = -1

cap.set(cv2.CAP_PROP_POS_FRAMES, 0)

# read frames
ret = True
while ret:
    ret, frame = cap.read()
    frame_nmr += 1
    if ret:
        df_ = results[results['frame_nmr'] == frame_nmr]
        for row_indx in range(len(df_)):
            try:
                # draw car
                car_bbox_str = df_.iloc[row_indx]['car_bbox'].replace('[ ', '[').replace('   ', ' ').replace('  ', ' ').replace(' ', ',')
                car_x1, car_y1, car_x2, car_y2 = ast.literal_eval(car_bbox_str)
                draw_border(frame, (int(car_x1), int(car_y1)), (int(car_x2), int(car_y2)), (0, 255, 0), 25,
                            line_length_x=200, line_length_y=200)

                # draw license plate
                license_bbox_str = df_.iloc[row_indx]['license_plate_bbox'].replace('[ ', '[').replace('   ', ' ').replace('  ', ' ').replace(' ', ',')
                x1, y1, x2, y2 = ast.literal_eval(license_bbox_str)
                cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 0, 255), 12)

                # Get car_id and check if it exists in our dictionary
                car_id = df_.iloc[row_indx]['car_id']
                if car_id not in license_plate:
                    print(f"Warning: Car ID {car_id} not in license_plate dictionary (frame {frame_nmr})")
                    continue
                
                # Get license plate text
                license_number = license_plate[car_id]['license_plate_number']
                
                # Calculate text size
                (text_width, text_height), _ = cv2.getTextSize(
                    license_number,
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1.0,  # Smaller font size
                    3     # Thinner text
                )
                
                # Calculate position for the text (above the license plate)
                text_x = int((x1 + x2 - text_width) / 2)
                text_y = int(y1 - 20)  # 20 pixels above the license plate
                
                # Make sure text is within frame
                if text_y < text_height + 10:
                    text_y = y1 + int(y2 - y1) + text_height + 10  # Place below if not enough space above
                
                if text_x < 0:
                    text_x = x1
                
                # Create background for text (white rectangle)
                bg_padding = 8
                bg_x1 = text_x - bg_padding
                bg_y1 = text_y - text_height - bg_padding
                bg_x2 = text_x + text_width + bg_padding
                bg_y2 = text_y + bg_padding
                
                # Ensure background is within frame bounds
                bg_x1 = max(0, bg_x1)
                bg_y1 = max(0, bg_y1)
                bg_x2 = min(frame.shape[1] - 1, bg_x2)
                bg_y2 = min(frame.shape[0] - 1, bg_y2)
                
                # Draw white background
                cv2.rectangle(frame, 
                             (int(bg_x1), int(bg_y1)), 
                             (int(bg_x2), int(bg_y2)), 
                             (255, 255, 255), 
                             -1)  # Filled rectangle
                
                # Draw text
                cv2.putText(frame,
                            license_number,
                            (text_x, text_y),
                            cv2.FONT_HERSHEY_SIMPLEX,
                            1.0,  # Font scale
                            (0, 0, 0),  # Black color
                            3)  # Thickness
                
            except Exception as e:
                print(f"Error processing row {row_indx} in frame {frame_nmr}: {e}")

        out.write(frame)
        frame = cv2.resize(frame, (1280, 720))
        
        # Uncomment to display frame
        # cv2.imshow('frame', frame)
        # cv2.waitKey(1)  # Changed from 0 to 1 for continuous playback

print("Video processing complete")
out.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# Video processing complete
